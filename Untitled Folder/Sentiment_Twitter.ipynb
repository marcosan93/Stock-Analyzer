# %% [markdown]
# # Sentiment Analysis of Tweets
# Regarding a specific stock

# %% [markdown]
# ### Importing Libraries

# %%
import twint
import nest_asyncio
nest_asyncio.apply()
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
import numpy as np
import matplotlib.pyplot as plt
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %% [markdown]
# ## Running Twint
# Scraping Twitter for tweets

# %%
# Search stock
subject = "$TSLA"

# %%
# %%capture
# Configuring Twint to search for the subject in the first specified city
c = twint.Config()

# The amount of tweets to return sorted by most recent
c.Limit = 200

# Input parameters
c.Search = subject

# Removing retweets
c.Filter_retweets = True

# No pictures or video
c.Media = False

# English only
c.Lang ='en'

# Excluding tweets with links
c.Links ='exclude'

# Making the results pandas friendly
c.Pandas = True

twint.run.Search(c)

# Assigning the DF
df = twint.storage.panda.Tweets_df

# %% [markdown]
# ### Function
# Assigning classes

# %%
def sentiment_class(score):
    """
    Labels each tweet based on its sentiment score
    """
    if score > 0:
        score = "Positive"
    elif score < 0:
        score ='Negative'
    else:
        score = 'Neutral'
        
    return score

# %%
# Instantiating the sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Grabbing the sentiment scores and assigning them to a new column
df['sentiment'] = [sid.polarity_scores(df.tweet.iloc[i])['compound'] for i in range(len(df))]

# Labeling the tweets in a new column
df['feel'] = df.sentiment.apply(sentiment_class)

# %% [markdown]
# ### Checking DataFrame
# With new columns and tweets.

# %%
df[['tweet', 'sentiment', 'feel']]
# Out:
#                                                  tweet  sentiment      feel
# 0    I'm just excited about what @PwC does about th...    -0.1141  Negative
# 1    i'm loaded up on robinhood. if $TSLA falls, i'...     0.0000   Neutral
# 2    I heard Tesla PT is $6000, so that should help...     0.5033  Positive
# 3    I must say I’m downright giddy to see this smu...    -0.4019  Negative
# 4    Earnings trade full disclosure: long Nov $tsla...     0.7096  Positive
# 5    NIO is a great study of what $TSLA’s last days...     0.7650  Positive
# 6    Q3 earnings approaches. The Force will always ...     0.0000   Neutral
# 7                                    Dude, it’s $TSLA.     0.0000   Neutral
# 8    1)Tomorrow’s $tsla call (loss call) will be ab...     0.0000   Neutral
# 9    But first you'll get people suspended on Twitt...    -0.5362  Negative
# 10   Sad to report that a friend that owns a Model ...    -0.3818  Negative
# 11   This will look like chump change compared to w...     0.3612  Positive
# 12   Heavy, Heavy Puts in Tesla from $235-$200 - Do...    -0.2755  Negative
# 13   It is troubling to CFA's that @TashaARK, a CFA...    -0.7579  Negative
# 14   Why is the market is saturated?  $TSLA deal is...     0.0000   Neutral
# 15   If Paulson Only Had My $CPE Avg. Cost.   $aapl...     0.0000   Neutral
# 16   Looking to add more $TWTR tomorrow if it goes ...     0.4404  Positive
# 17   $FDX Up After $UPS Earnings   $aapl $amzn $agn...     0.0000   Neutral
# 18   Shares of $KHC Rose Today   $aapl $amzn $agn $...     0.2960  Positive
# 19   Down 400 Monday Today nothing I have been red ...     0.5106  Positive
# 20   Still got a piece of the $260p $NFLX. Almost t...     0.2382  Positive
# 21   Did Neumann Mock SoftBank Walking With No Shoe...    -0.6124  Negative
# 22   Agree. It "should" scare NHTSA into creating a...     0.4215  Positive
# 23   *checks alarms*  Daily 9am alarm still active....     0.4215  Positive
# 24   Maybe the best selling of its class no matter ...     0.4767  Positive
# 168  $TSLA can launch a "Life with Model 3" but can...     0.5927  Positive
# 169  If any of these motives is true, especially a ...     0.8467  Positive
# 170  Depends on their motives. I see three, welcome...     0.4588  Positive
# 171  Why did CCP give $TSLA so much money and assis...     0.6767  Positive
# 172  @lopezlinette is no where to be found. Seems l...     0.6808  Positive
# 173  Have you checked FCF like this: FCF = operatin...     0.7860  Positive
# 174  Remember, at this point in time, you shouldn't...     0.4404  Positive
# 175  And also the fact that @softbank Dumb $$$ was ...    -0.8360  Negative
# 176  Depends on their motives. I see three motives,...     0.4588  Positive
# 177  The damage are the occurred losses of $SCTY ru...    -0.5946  Negative
# 178  $TSLA climate change is a wonderful example of...     0.5719  Positive
# 179  I don't see net income being positive without ...     0.2658  Positive
# 180  With $TSLAQ Q3 numbers expectable bad, Y and f...    -0.2732  Negative
# 181  $tsla leaking an earnings surprise. Maybe we’l...     0.2732  Positive
# 182  Still in San Diego. @Keubiko , I need a physic...     0.4939  Positive
# 183  I don't know. But it is a derivative lawsuit, ...    -0.4588  Negative
# 184  What are the damages to $TSLA shareholders?  C...    -0.7149  Negative
# 185  🚨🚨 Options activity  Purchase of 60 12/20/19 $...    -0.7184  Negative
# 186  $TSLA - I wonder how many shares of Tesla that...    -0.0258  Negative
# 187  The SolarCity lawsuit would involve Elon and t...    -0.2263  Negative
# 188  $NYSI $QQQ $IWM $RUT $DIA $FB $GOOG $XLF $XLE ...     0.4019  Positive
# 189  Trades I’m likely going to make today and this...     0.0000   Neutral
# 190  working on an uptrend, heading to make a new h...     0.0000   Neutral
# 191  @elonmusk model y and 3 are very unattractive ...    -0.9240  Negative
# 192                             #Buy $TSLA  Seriously.    -0.1779  Negative
# 193  @elonmusk @Porsche let me down with their con ...     0.8286  Positive
# 194  @jonnajarian @petenajarian what’s your thought...     0.0000   Neutral
# 195     S.O.S. received and acknowledged. $tsla $tslaQ     0.0000   Neutral
# 196  The only Tech company without competition is $...     0.0000   Neutral
# 197  Today's Watchlist:  $NVDA $CRWD $TWTR $TSLA $F...     0.0000   Neutral
# 198  Have you considered $TSLA longs with a even a ...     0.0000   Neutral
# 199  You as a $tsla cheerleader shouldn't talk mutc...    -0.8065  Negative

# %% [markdown]
# ## Plotting the Sentiment

# %% [markdown]
# ### Donut Chart for Tweets

# %%
print(df.feel.value_counts())

plt.style.use('fivethirtyeight')
plt.rcParams['font.size'] = 30
fig, ax = plt.subplots(figsize=(10,10))

ax.pie(list(df.feel.value_counts()), 
       labels=df.feel.value_counts().index, 
       autopct='%1.1f%%',
       wedgeprops = { 'linewidth': 7, 'edgecolor': 'whitesmoke' })

circle = plt.Circle((0,0), 0.3, color='whitesmoke')
fig = plt.gcf()
fig.gca().add_artist(circle)

ax.set_title(f'Count of Tweets for \n{subject}')
ax.axis('equal')
plt.show()
# Out:
# Positive    86
# Negative    62
# Neutral     52
# Name: feel, dtype: int64

# %% [markdown]
# ### Histogram Plot for the Sentiment scores

# %%
plt.style.use('fivethirtyeight')

fig, ax = plt.subplots(figsize=(10,6))

# Plotting the sentiment scores
ax.hist(df['sentiment'], bins=5)

plt.title(f"Sentiment for {subject}")
ax.set_xticks([-1,0,1])
ax.set_xticklabels(['negative', 'neutral', 'positive'])
plt.xlabel("Sentiment")
plt.ylabel("# of Tweets")
plt.show()
